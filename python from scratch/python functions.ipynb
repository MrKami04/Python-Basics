# %% [markdown]
# - isinstance(): return true if data present.
# - len(): calculate length of list dict etc
# - type(): find out types of the variable
# - list(): create a list
# - insert(): insert new values in existing someone value
# - append(): add item in list
# - extend(): append element from another list to curret list
# - remove(): remove list item
# - pop(): remove the specified index
# - del : remove specific index
# - clear(): empties the list
# - range(): range
# - sort(): order, arrange
# - copy(): copy
# -
